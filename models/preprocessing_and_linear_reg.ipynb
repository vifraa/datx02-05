# %%
import pandas as pd
from sklearn.model_selection import train_test_split

L = []

for i in range(90):
    L.append(f"rep{i}")
    L.append(f"weight{i}")

L2 = ["age", "person_weight", "gender", "pre-performance", "performance"]
L += L2

# Read the CSV file.
data = pd.read_csv("regression_dataframes.csv", names=L)

# Shuffle the dataset.
data_shuffled = data.sample(frac=1.0, random_state=0)

# Split into input part X and output part Y.
X = data_shuffled.drop('performance', axis=1)

Y = data_shuffled['performance']
Y.head()

# # Partition the data into training and test sets.
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X.head()
# Out:
#     rep0  weight0  rep1  weight1  ...  weight89   age  person_weight  gender
# 26   8.0     34.0   8.0     34.0  ...      46.0  50.0           70.0     1.0
# 86   5.0     46.0   5.0     46.0  ...      59.0  38.0           68.0     1.0
# 2    5.0     30.0   5.0     30.0  ...      38.0  25.0           75.0     0.0
# 55   8.0     44.0   8.0     44.0  ...      61.0  31.0          101.0     1.0
# 75   5.0     40.0   5.0     40.0  ...      45.0  39.0           94.0     0.0
#
# [5 rows x 183 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

#Träna modellen
lr = LinearRegression()
lr.fit(Xtrain,Ytrain)

#Använd på testsettet
Ypred = lr.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 0.84
# Coefficient of determination: 0.99

# %%
#Ridge regression
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(Xtrain, Ytrain)
# Ridge()
ridge_Ypred = ridge.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, ridge_Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, ridge_Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 0.94
# Coefficient of determination: 0.99

# %%
from sklearn import linear_model
lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(Xtrain,Ytrain)
lasso_Ypred = lasso.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, lasso_Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, lasso_Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 0.82
# Coefficient of determination: 0.99

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

#Preprocess the simpler modell
#Labels 

L3 = ["age", "person_weight", "gender", "preperformance", "performance"]

# Read the CSV file.
data = pd.read_csv("regression_dataframes.csv", names=L3)

# Shuffle the dataset.
data_shuffled = data.sample(frac=1.0, random_state=0)

# Split into input part X and output part Y.
X = data_shuffled.drop('performance', axis=1)

Y = data_shuffled['performance']
Y.head()

# # Partition the data into training and test sets.
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state=0)
