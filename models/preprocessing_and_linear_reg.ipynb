# %%
import pandas as pd
from sklearn.model_selection import train_test_split

L = []

for i in range(90):
    L.append(f"rep{i}")
    L.append(f"weight{i}")

L2 = ["age", "person_weight", "gender", "pre-performance", "performance"]
L += L2

# Read the CSV file.
data = pd.read_csv("regression_dataframes2.csv", names=L)

# Shuffle the dataset.
data_shuffled = data.sample(frac=1.0, random_state=0)

# Split into input part X and output part Y.
X = data_shuffled.drop('performance', axis=1)

Y = data_shuffled['performance']
Y.head()

# # Partition the data into training and test sets.
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X.head()
# Out:
#     rep0  weight0  rep1  weight1  ...   age  person_weight  gender  pre-performance
# 26   8.0     34.0   8.0     34.0  ...  50.0           70.0     1.0             45.0
# 86   5.0     46.0   5.0     46.0  ...  38.0           68.0     1.0             58.0
# 2    5.0     30.0   5.0     30.0  ...  25.0           75.0     0.0             38.0
# 55   8.0     44.0   8.0     44.0  ...  31.0          101.0     1.0             58.0
# 75   5.0     40.0   5.0     40.0  ...  39.0           94.0     0.0             50.0
#
# [5 rows x 184 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

#Träna modellen
lr = LinearRegression()
lr.fit(Xtrain,Ytrain)

#Använd på testsettet
Ypred = lr.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 0.84
# Coefficient of determination: 0.99

# %%
#Ridge regression
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(Xtrain, Ytrain)
# Ridge()
ridge_Ypred = ridge.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, ridge_Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, ridge_Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 0.94
# Coefficient of determination: 0.99

# %%
from sklearn import linear_model
lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(Xtrain,Ytrain)
lasso_Ypred = lasso.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, lasso_Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, lasso_Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 0.79
# Coefficient of determination: 0.99
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41118081332707135, tolerance: 0.39511020477807246
#   positive)

# %%
#######################################
##Simpler model with no training logs##
#######################################

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

#Preprocess the simpler modell
#Labels 

L = []
for i in range(90):
    L.append(f"rep{i}")
    L.append(f"weight{i}")

L3 = ["age", "person_weight", "gender", "preperformance", "performance"]
L += L3

# Read the CSV file.
data = pd.read_csv("regression_dataframes2.csv", names=L)
data = data[L3]
data = data.dropna()
# Shuffle the dataset.
data_shuffled = data.sample(frac=1.0, random_state=0)

# Split into input part X and output part Y.
X = data_shuffled.drop('performance', axis=1)

Y = data_shuffled['performance']
Y.head()

# # Partition the data into training and test sets.
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
data.head()
# Out:
#     age  person_weight  gender  preperformance  performance
# 0  48.0           86.0     2.0            46.0    61.066083
# 1  32.0           73.0     1.0            54.0    69.396036
# 2  25.0           75.0     0.0            38.0    47.263152
# 3  18.0           62.0     2.0            52.0    63.815772
# 4  31.0           90.0     1.0            46.0    57.693962

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

#Träna modellen
lr = LinearRegression()
lr.fit(Xtrain,Ytrain)

#Använd på testsettet
Ypred = lr.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 1.18
# Coefficient of determination: 0.98

# %%
#Ridge regression
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(Xtrain, Ytrain)
# Ridge()
ridge_Ypred = ridge.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, ridge_Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, ridge_Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 1.18
# Coefficient of determination: 0.98

# %%
from sklearn import linear_model
lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(Xtrain,Ytrain)
lasso_Ypred = lasso.predict(Xtest)

print('Mean squared error: %.2f'
      % mean_squared_error(Ytest, lasso_Ypred))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(Ytest, lasso_Ypred))

# print("Avvikelser \n",Ypred-Ytest)
# Out:
# Mean squared error: 1.20
# Coefficient of determination: 0.98
